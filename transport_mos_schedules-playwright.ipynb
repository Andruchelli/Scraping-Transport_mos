# %% [markdown]
# ## Данные о маршрутах общественного транспорта с Единого транспортного портала
#
# Сбор данных о маршрутах общественного транспорта с сайта [transport.mos.ru](https://transport.mos.ru/transport/schedule) (в ознакомительных целях).

# %%
# Устанавливаем библиотеку playwright
#pip install playwright nest_asyncio

# %%
# Устанавливаем браузер для работы playwright
#!playwright install

# %%
import nest_asyncio
import asyncio
from playwright.async_api import async_playwright

import pandas as pd

from datetime import datetime

nest_asyncio.apply()

# %% [markdown]
# Работа с данными заключается в сборе информации с веб-страниц маршрутов общественного транспорта.
#
# Сбор данных производится в несколько этапов:
#
# * сбор url-ссылок на маршруты;
#
# * переход по ссылкам;
#
# * сбор данных о наборе остановок рейсов маршрута.

# %%
# Создаём пустой список, в который будут записываться ссылки маршрутов с сайта
links_routes = []

# Создаём переменную для записи даты и времени получения данных
timestamp = datetime.now().strftime("%d.%m.%Y %H:%M")

# Создаём функцию для скроллинга страницы до конца, чтобы иметь возможность загрузить ссылки на все маршруты
async def scroll_to_bottom(page):
    previous_height = await page.evaluate("document.body.scrollHeight")
    
    while True:
        await page.evaluate("window.scrollTo(0, document.body.scrollHeight);")
        
        await page.wait_for_timeout(1000)
        new_height = await page.evaluate("document.body.scrollHeight")
        if new_height == previous_height:
            break
        
        previous_height = new_height

# Создаём основную функцию, где будет производиться сбор ссылок на страницы с маршрутами
async def run_playwright():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)
        page = await browser.new_page()
        # переходим по ссылке с списком маршрутов
        await page.goto("https://transport.mos.ru/transport/schedule")
        
        # Обращаемся к функции для скроллинга страницы
        await scroll_to_bottom(page)
        
        # Ожидаем прогрузки на странице данных в селекторе ссылок 
        await page.wait_for_selector("a")

        # Получаем данные из тега <a class="ts-row ">
        data = await page.evaluate('''() => {
            return Array.from(document.querySelectorAll('a.ts-row ')).map(a => a.href);
        }''')
        
        # Поэлементно добавляем данные, полученные выше, в список
        for item in data:
            links_routes.append(item)

        await browser.close()
        
import asyncio
asyncio.run(run_playwright())
# Out:
# python3.9(58540) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.

# %%
# Выводим количество элементов в списке
len(links_routes)
# Out:
# 1117

# %%
# Создаём функцию для сбора данных со страницы маршрута
async def data_page(page, radio_count):
    global data_list # объявление глобальной переменной, чтобы она могла быть использована в любой части программы
    # Пробуем достать данные из кода страницы
    try:
        # <i class ="..."> - тип маршрута (внутри тега)
        h1_element = await page.query_selector("h1.h3mb")
        i_elements = await h1_element.query_selector_all("i")
        class_name = [await i.evaluate('el => el.className') for i in i_elements]
        print(f'1 - {class_name}')
        try:
            # <h1 class ="h3mb"> - номер маршрута (текст в теге)
            h1_text = await h1_element.inner_text()
        except:
            h1_text = "-"
    except:
        class_name = "-"
    
    try:
        # <span id="schedule-route-header"> - название рейса (текст внутри "span")
        span_header_element = await page.query_selector("span#schedule-route-header")
        try:
            span_header_text = await span_header_element.inner_text()
        except:
            span_header_text = "-"
    except:
        span_header_text = ""
    
    try:
        # <div id="schedule-table"> - остановочные пункты
        stops_elements = await page.query_selector_all("div#schedule-table")
        stops = [await d.inner_text() for d in stops_elements]
        print(f'4 - {stops}')
        print("----------")
    except:
        stops = "-"
    
    # Добавляем данные, полученные выше, в список
    data_list.append([class_name, h1_text, span_header_text, stops, radio_count])
    
    # Возвращаем список с данными
    return data_list

# %%
# Создаём пустой список, куда будут добавляться данные, собранные с веб-страницы
data_list = []

# Создаём функцию для проверки наличия кнопок переключения рейсов
async def check_div_availability():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=False)
        page = await browser.new_page()
        
        # Переходим по собранным ссылкам 
        for link in links_routes:
            await page.goto(link)

            await page.wait_for_timeout(2000)
            #result = await data_page(page)

            # Собираем все радиокнопки (рейсы в одном направлении) на странице с помощью xpath селектора        
            try:
                radios = await page.query_selector_all("//div[@id='mgt_schedule_trip']//span[@class='sp_all']")
                print(f"Количество кнопок {len(radios)}")
                radio_count = len(radios)
                for radio in radios:
                    try:
                        await radio.check() # активируем радиокнопку
                        await page.wait_for_timeout(2000)
                        #result = await data_page(page, radio_count)
                    except:
                        continue
            except:
                continue
            result = await data_page(page, radio_count)

            # Проверяем наличие тега <i class="i.ic.ic-change-a-b"> для обнаружения рейсов обратнгом направления
            try:
                button_direction = await page.query_selector("i.ic.ic-change-a-b")
                # Кликаем на кнопку смены направления
                await button_direction.click()
                await page.wait_for_timeout(2000)
                
                try:
                    # Собираем все радиокнопки с помощью xpath селектора        
                    radios = await page.query_selector_all("//div[@id='mgt_schedule_trip']//span[@class='sp_all']")
                    print(f"Количество кнопок {len(radios)}")
                    radio_count = len(radios)
                    
                    for radio in radios:
                        try:
                            await radio.check() # активируем радиокнопку
                            await page.wait_for_timeout(2000)
                            result = await data_page(page, radio_count)
                        except:
                            continue

                except:
                    continue
            except:
                continue
            
            # Передаём полученные данные для дальнейшего сбора информации с помощью функции "data_page"
            result = await data_page(page, radio_count)
            
            await page.wait_for_timeout(2000)
            
        await browser.close()
        
asyncio.run(check_div_availability())
# Out:
# python3.9(61288) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Количество кнопок 2
# 1 - ['ic ic-xl icon-tramway']
# 4 - ['МЦД Калитники\nОктябрьское трамвайное депо\nМ. Калитниковский пр.\nВоловья ул.\nБ. Калитниковская ул.\nК/т "Победа" - Детский театр\nМетро "Пролетарская"\nДинамовская улица\nНовоспасский мост\nКожевническая улица\nПавелецкий вокзал\nПавелецкий вокзал\nМетро "Павелецкая"\nВишняковский переулок\nМетро "Третьяковская"\nМетро "Новокузнецкая"\nКомиссариатский мост\nЯузские ворота\nВоронцово Поле\nКазарменный пер.\nПокровские Ворота\nБ. Харитоньевский пер.\nМетро "Чистые пруды"\nБ. Харитоньевский пер.\nПокровские Ворота\nКазарменный пер.\nВоронцово Поле\nЯузские ворота\nКомиссариатский мост\nМетро "Новокузнецкая"\nМетро "Третьяковская"\nВишняковский переулок\nМетро "Павелецкая"\nПавелецкий вокзал\nКожевническая улица\nНовоспасский мост\nДинамовская улица\nМетро "Пролетарская"\nКинотеатр "Победа" - Детский театр\nАбельмановская Застава\nБ. Калитниковская ул.\nВоловья ул.\nМалый Калитниковский проезд']
# ----------
# Количество кнопок 0
# 1 - ['ic ic-xl icon-tramway']
# 4 - ['Чертаново Южное\nПоликлиника\nОВД "Чертаново Южное"\nЧертановская улица, 53\nКировоградские пруды\nЧертановская ул., 44\nЧертаново Центральное\nДетская стоматологическая п-ка\nЧертановская ул., 28\nКинотеатр "Ашхабад"\nШкольный парк\nФутбольная школа Чертаново\nСумской проезд\nВерхний Чертановский пруд\nМетро "Чертановская"\nБалаклавский проспект\nЧерноморский бульв.\nСимферопольский бульвар, 20\nМетро "Каховская"\nБолотниковская улица']
# ----------
# Количество кнопок 0
# 1 - ['ic ic-xl icon-tramway']
# 4 - 

# ----------
# Количество кнопок 0
# 1 - ['ic ic-xl ic-bus']
# 4 - ['Метро "Молодёжная"\nУлица Маршала Сергеева\nДом культуры\nМолодогвардейская ул.\nПартизанская ул.\nМЦД Рабочий Посёлок\nУл. Ивана Франко\nПолоцкая улица, 8\nУл. Екатерины Будановой\nУл. Коцюбинского\nУлица Ивана Франко, 22\nПрефектура ЗАО\nМетро "Кунцевская"\nКастанаевская улица']
# ----------
# Количество кнопок 0
# 1 - ['ic ic-xl ic-bus']
# 4 - ['Парк "Фили"\nУл. Барклая\nБ. Филевская ул., 23\n51-я гор. б-ца\nМинская ул.\nМетро "Филёвский парк"\nПлощадь Ромена Роллана\nПарк Победы\nМетро "Минская"\nКаменная плотина\nМосфильмовский пруд\nМосфильмовская ул.\nМетро "Ломоносовский проспект"\nМенделеевская ул.\nБиблиотека МГУ\nУлица Лебедева\nМетро "Университет"\nМетро "Университет"\nДрамтеатр\nЛенинский проспект\nЦентр здоровья детей\nЧерёмушкинский рынок\nУл. Ивана Бабушкина\nМетро "Профсоюзная"\nМетро "Профсоюзная"\nНовочеремушкинская ул.\nМФЦ Черёмушки\n23-й квартал Новых Черёмушек']
# ----------
# Количество кнопок 0
# 1 - ['ic ic-xl ic-bus']
# 4 - ['Парк "Фили"\nУл. Барклая\nБ. Филевская ул., 23\n51-я гор. б-ца\nМинская ул.\nМетро "Филёвский парк"\nПлощадь Ромена Роллана\nПарк Победы\nМетро "Минская"\nКаменная плотина\nМосфильмовский пруд\nМосфильмовская ул.\nМетро "Ломоносовский проспект"\nМенделеевская ул.\nБиблиотека МГУ\nУлица Лебедева\nМетро "Университет"\nМетро "Университет"\nДрамтеатр\nЛенинский проспект\nЦентр здоровья детей\nЧерёмушкинский рынок\nУл. Ивана Бабушкина\nМетро "Профсоюзная"\nМетро "Профсоюзная"\nНовочеремушкинская ул.\nМФЦ Черёмушки\n23-й квартал Новых Черёмушек']
# ----------
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In [604], line 60
#      56             await page.wait_for_timeout(2000)
#      58         await browser.close()
# ---> 60 asyncio.run(check_div_availability())
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/nest_asyncio.py:35, in _patch_asyncio.<locals>.run(main, debug)
#      33 task = asyncio.ensure_future(main)
#      34 try:
# ---> 35     return loop.run_until_complete(task)
#      36 finally:
#      37     if not task.done():
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/nest_asyncio.py:90, in _patch_loop.<locals>.run_until_complete(self, future)
#      87 if not f.done():
#      88     raise RuntimeError(
#      89         'Event loop stopped before Future completed.')
# ---> 90 return f.result()
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception
#     202 return self._result
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/asyncio/tasks.py:256, in Task.__step(***failed resolving arguments***)
#     252 try:
#     253     if exc is None:
#     254         # We use the `send` method directly, because coroutines
#     255         # don't have `__iter__` and `__next__` methods.
# --> 256         result = coro.send(None)
#     257     else:
#     258         result = coro.throw(exc)
#
# Cell In [604], line 8, in check_div_availability()
#       6 page = await browser.new_page()
#       7 for link in links_routes:
# ----> 8     await page.goto(link)
#      10     await page.wait_for_timeout(2000)
#      11     #result = await data_page(page)
#      12
#      13     # Собираем все радиокнопки с помощью xpath селектора
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/playwright/async_api/_generated.py:9260, in Page.goto(self, url, timeout, wait_until, referer)
#    9199 async def goto(
#    9200     self,
#    9201     url: str,
#    (...)
#    9207     referer: typing.Optional[str] = None
#    9208 ) -> typing.Optional["Response"]:
#    9209     """Page.goto
#    9210
#    9211     Returns the main resource response. In case of multiple redirects, the navigation will resolve with the first
#    (...)
#    9256     Union[Response, None]
#    9257     """
#    9259     return mapping.from_impl_nullable(
# -> 9260         await self._impl_obj.goto(
#    9261             url=url, timeout=timeout, waitUntil=wait_until, referer=referer
#    9262         )
#    9263     )
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/playwright/_impl/_page.py:475, in Page.goto(self, url, timeout, waitUntil, referer)
#     468 async def goto(
#     469     self,
#     470     url: str,
#    (...)
#     473     referer: str = None,
#     474 ) -> Optional[Response]:
# --> 475     return await self._main_frame.goto(**locals_to_params(locals()))
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/playwright/_impl/_frame.py:139, in Frame.goto(self, url, timeout, waitUntil, referer)
#     129 async def goto(
#     130     self,
#     131     url: str,
#    (...)
#     134     referer: str = None,
#     135 ) -> Optional[Response]:
#     136     return cast(
#     137         Optional[Response],
#     138         from_nullable_channel(
# --> 139             await self._channel.send("goto", locals_to_params(locals()))
#     140         ),
#     141     )
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/playwright/_impl/_connection.py:62, in Channel.send(self, method, params)
#      61 async def send(self, method: str, params: Dict = None) -> Any:
# ---> 62     return await self._connection.wrap_api_call(
#      63         lambda: self.inner_send(method, params, False)
#      64     )
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/playwright/_impl/_connection.py:492, in Connection.wrap_api_call(self, cb, is_internal)
#     490 self._api_zone.set(_extract_stack_trace_information_from_stack(st, is_internal))
#     491 try:
# --> 492     return await cb()
#     493 finally:
#     494     self._api_zone.set(None)
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/site-packages/playwright/_impl/_connection.py:100, in Channel.inner_send(self, method, params, return_as_dict)
#      98 if not callback.future.done():
#      99     callback.future.cancel()
# --> 100 result = next(iter(done)).result()
#     101 # Protocol now has named return values, assume result is one level deeper unless
#     102 # there is explicit ambiguity.
#     103 if not result:
#
# File ~/.pyenv/versions/3.9.0/lib/python3.9/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception
#     202 return self._result
#
# TimeoutError: Timeout 30000ms exceeded.

# %%
len(data_list)
# Out:
# 20

# %%
data_list
# Out:
# [[['ic ic-xl icon-tramway'],
#   ' А',
#   'МЦД Калитники - Октябрьское трамвайное депо',
#   ['МЦД Калитники\nОктябрьское трамвайное депо\nМ. Калитниковский пр.\nВоловья ул.\nБ. Калитниковская ул.\nК/т "Победа" - Детский театр\nМетро "Пролетарская"\nДинамовская улица\nНовоспасский мост\nКожевническая улица\nПавелецкий вокзал\nПавелецкий вокзал\nМетро "Павелецкая"\nВишняковский переулок\nМетро "Третьяковская"\nМетро "Новокузнецкая"\nКомиссариатский мост\nЯузские ворота\nВоронцово Поле\nКазарменный пер.\nПокровские Ворота\nБ. Харитоньевский пер.\nМетро "Чистые пруды"\nБ. Харитоньевский пер.\nПокровские Ворота\nКазарменный пер.\nВоронцово Поле\nЯузские ворота\nКомиссариатский мост\nМетро "Новокузнецкая"\nМетро "Третьяковская"\nВишняковский переулок\nМетро "Павелецкая"\nПавелецкий вокзал\nКожевническая улица\nНовоспасский мост\nДинамовская улица\nМетро "Пролетарская"\nКинотеатр "Победа" - Детский театр\nАбельмановская Застава\nБ. Калитниковская ул.\nВоловья ул.\nМалый Калитниковский проезд\nОктябрьское трамвайное депо\nМЦД Калитники'],
#   2],
#  [['ic ic-xl icon-tramway'],
#   ' А',
#   'МЦД Калитники - Октябрьское трамвайное депо',
#   0],
#  [['ic ic-xl icon-tramway'],
#   ' 3а',
#   'Метро "Чертановская" - Стремянный переулок ',
#   ['Метро "Чертановская"\nЧерноморский бульв.\nСимферопольский бульвар, 20\nМетро "Каховская"\nБолотниковская улица\nФруктовая улица\nНахимовский проспект\nСимферопольский бульвар\nХлебозаводский пр.\n1-й Нагатинский пр.\nНижние Котлы\nПлатформа Нагатинская\nМетро "Нагатинская"\nМЦК Верхние Котлы\nСтадион "Труд"\nДаниловская мануфактура\nПлатформа Тульская\nМетро "Тульская"\nСерпуховская Застава\nСвято-Данилов монастырь\nУлица Даниловский Вал\n1-й Павловский переулок\nДубининская улица, 57\nЖуков проезд\nСтремянный переулок'],
#   0],
#  [['ic ic-xl ic-bus'],
#   ' 3а (Зеленоград)',
#   'МЦД Зеленоград-Крюково - Западная ',
#   ['МЦД Зеленоград-Крюково\nЗападная'],
#   0],
#  [['ic ic-xl ic-bus'],
#   ' 3а (Зеленоград)',
#   'Западная - МЦД Зеленоград-Крюково ',
#   ['Западная\nАвтобаза\nАЗС\nКолледж\nБерёзка\n1-й Торговый центр\nКинотеатр "Электрон"\nМ-н "Детский мир"\nМ-н "Океан"\nДом быта\nМ-н "Товары для дома"\nПарк Победы\nМИЭТ\nСолнечная ал.\nПоликлиника № 105\nУниверсам\nМЦД Зеленоград-Крюково'],
#   0],
#  [['ic ic-xl ic-bus'],
#   ' 12а (Зеленоград)',
#   'МЦД Зеленоград-Крюково - Школа-интернат № 7 ',
#   ['МЦД Зеленоград-Крюково\nПанфиловский проспект\nОктябрьская\n1-й Торговый центр\nКинотеатр "Электрон"\nУлица Юности\nМузыкальная школа\nСтуденческая\nМосковский проспект\nШкола-интернат № 7'],
#   0],
#  [['ic ic-xl ic-bus'],
#   ' 12а (Зеленоград)',
#   'МЦД Зеленоград-Крюково - Школа-интернат № 7 ',
#   ['МЦД Зеленоград-Крюково\nПанфиловский проспект\nОктябрьская\n1-й Торговый центр\nКинотеатр "Электрон"\nУлица Юности\nМузыкальная школа\nСтуденческая\nМосковский проспект\nШкола-интернат № 7'],
#   0],
#  [['ic ic-xl icon-tramway'],
#   ' 39а',
#   'Метро "Университет" - Стремянный переулок ',
#   ['Метро "Университет"\nДрамтеатр\nЛенинский проспект\nЦентр здоровья детей\nЧерёмушкинский рынок\nУниверситетская клиника РУДН\nДарвиновский музей\nУл. Губкина\nУлица Ляпунова\nУл. Бардина\nПросп. 60-летия Октября\nМетро "Ленинский проспект" (южный вход)\nМетро "Ленинский проспект" (северный вход)\nУл. Орджоникидзе\nДонской монастырь\nСерпуховский Вал\nХавская ул.\nДаниловский рынок\nСерпуховская Застава\nСвято-Данилов монастырь\nУлица Даниловский Вал\n1-й Павловский переулок\nДубининская улица, 57\nЖуков проезд\nСтремянный переулок'],
#   0],
#  [['ic ic-xl icon-tramway'],
#   ' 39а',
#   'Метро "Университет" - Стремянный переулок ',
